# %%
import streamlit as st
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import pickle

# %%
# Load the dictionary from the file
with open('action_to_idx.pkl', 'rb') as f:
    action_to_idx = pickle.load(f)

# %%
class LSTM(nn.Module):
    def __init__(self, feature_sizes, embedding_dim=64, hidden_size=128, dropout=0.5):
        super().__init__()
        # Create an embedding for each feature
        self.embeddings = nn.ModuleList([
            nn.Embedding(num_embeddings=size, embedding_dim=embedding_dim)
            for size in feature_sizes
        ])
        
        # Dropout module for regularization
        self.dropout = nn.Dropout(dropout)
        
        # First LSTM layer: input is concatenated embeddings
        self.lstm1 = nn.LSTM(
            input_size=embedding_dim * len(feature_sizes),
            hidden_size=hidden_size,
            batch_first=True
        )
        # A linear projection to match the dimensions for the first residual connection
        self.residual_proj1 = nn.Linear(embedding_dim * len(feature_sizes), hidden_size)
        
        # Second LSTM layer: input and output are both hidden_size
        self.lstm2 = nn.LSTM(
            input_size=hidden_size,
            hidden_size=hidden_size,
            batch_first=True
        )
        
        # Activation function
        self.activation = nn.ReLU()
        
        # Final fully-connected layer to produce logits over actions
        self.fc = nn.Linear(hidden_size, len(action_to_idx))
        
    def forward(self, x):
        # x shape: (batch_size, time_steps, num_features)
        batch_size, seq_len, num_feats = x.size()
        
        # Process each feature through its embedding
        embedded = []
        for i in range(num_feats):
            emb = self.embeddings[i](x[:, :, i])  # (batch_size, seq_len, embedding_dim)
            embedded.append(emb)
        x_emb = torch.cat(embedded, dim=-1)  # (batch_size, seq_len, embedding_dim*num_feats)
        x_emb = self.dropout(x_emb)
        
        # First LSTM layer
        out1, _ = self.lstm1(x_emb)  # (batch_size, seq_len, hidden_size)
        # Residual: project input embeddings and add to LSTM output
        res1 = self.residual_proj1(x_emb)  # (batch_size, seq_len, hidden_size)
        out1 = self.activation(out1 + res1)
        out1 = self.dropout(out1)
        
        # Second LSTM layer
        out2, _ = self.lstm2(out1)  # (batch_size, seq_len, hidden_size)
        # Residual: add the output of the first LSTM layer (out1) to the output of the second
        out2 = self.activation(out2 + out1)
        out2 = self.dropout(out2)
        
        # Use the output of the final time step for prediction
        logits = self.fc(out2[:, -1, :])  # (batch_size, num_actions)
        return logits

# %%
@st.cache_resource
def load_model():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    checkpoint = torch.load('model.pth', map_location=device)

    # Load mappings and parameters first
    feature_to_idx = checkpoint['feature_to_idx']
    action_to_idx = checkpoint['action_to_idx']
    idx_to_action = {v: k for k, v in action_to_idx.items()}
    features_order = checkpoint['features_order']
    feature_sizes = checkpoint['feature_sizes']
    
    # Recreate model architecture
    model = LSTM(feature_sizes=feature_sizes)
    model.load_state_dict(checkpoint['model_state_dict'])
    model.to(device)
    model.eval()

    return model, feature_to_idx, action_to_idx, idx_to_action, features_order

# Load from the checkpoint
model, feature_to_idx, action_to_idx, idx_to_action, features_order = load_model()
# Out:
# 2025-02-23 23:25:18.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:25:18.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:25:18.635 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# /var/folders/qd/1pjv967d1ylfl4mzr8flbvb00000gn/T/ipykernel_79794/901656429.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('model.pth', map_location=device)
# 2025-02-23 23:25:19.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:25:19.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# Initialize session state
if 'history' not in st.session_state:
    st.session_state.history = []
if 'current_features' not in st.session_state:
    st.session_state.current_features = {feat: 0 for feat in features_order}
# Out:
# 2025-02-23 23:25:39.536 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:25:39.537 Session state does not function when running a script without `streamlit run`
# 2025-02-23 23:25:39.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:25:39.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:25:39.540 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:25:39.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:25:39.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# List of features with dropdowns
DROPDOWN_FEATURES = [
    "city", "country", "device_family", "device_type", 
    "language", "os_name", "user_properties_roles"
]

# List of event_type actions (truncated for display)
event_actions = [
    'session_end', 'application-window-opened', 'session_start', 'agency-dashboard::layout:render', 'agency-dashboard:::view', 'agency-dashboard::widget:render', 'agency-dashboard::configurable-table:render', '::nav-header:user-signed-out', 
    'dashboard:my-book:configurable-table:render', 'dashboard:my-book:widget:render', 'triaged-submission-list:my-book:configurable-table:render', 'triaged-submission-list:my-book::view', 'dashboard:my-book:layout:render', 'dashboard:my-book::view',
    '::nav-header:action-center-click', 'action-center:::view', 'account:::view', 'account-lines:::view', 'account-lines::layout:render', 'account-lines::widget:render', 'account-lines::configurable-table:render', ':all-accounts:configurable-table:render', 
    ':all-accounts:widget:render', ':all-accounts:layout:render', ':all-accounts::view', 'submissions:policy-definition::submit-click', 'submissions:all-policy:configurable-table:render', 'submissions:all-policy::view', 'submissions:triaged_submissions-definition::view',
    'triaged-submission:triaged_submissions-definition:layout:render', 'triaged-submission:triaged_submissions-definition::view', 'triaged-submission:triaged_submissions-definition:widget:render', 'triaged-submission-list:triaged_submissions-definition:configurable-table:render', 
    'triaged-submission-list:triaged_submissions-definition::view', 'submissions:policy-definition::view', 'submissions:policy-definition:configurable-table:render', 'submissions:policy-create::view', 'submissions:policy-create::submit-click', 'account-lines:::change-rating-click', 
    'account-property-rating:perils:configurable-table:render', 'account-property-rating:perils::view', 'action-center:::submit-click', 'action-center:action-details::view', 'action-center:::close-click', 'dashboard:my-book::action-click', 'action-center:action-details:response-form:submit-click', 
    'account-lines::templeton-docs:create-document-click', 'account-property-rating:perils:perils-table:add-click', 'account-property-rating:perils:perils-table:edit-click', 'account-property-rating:perils:perils-table:delete-click', 'dashboard:portfolio-insights:layout:render', 'dashboard:portfolio-insights::view', 
    'dashboard:portfolio-insights:widget:render', 'dashboard:my-book:recent-actions-table:action-click', 'account-auto-rating:::view', 'account-auto-rating::configurable-table:render', 'account-property-rating:perils:layers:add-click', 'account-property-rating:perils:model-request-details:save-click', 'submissions:exposures-create::submit-click', 
    'submissions:all-exposures:configurable-table:render', 'submissions:all-exposures::view', 'submissions:exposures-create::view', 'dashboard:my-book:recent-actions-table:account-click', '::configurable-table:render', '::layout:render', '::widget:render', 'EMPTY', 'submissions:all-account::view', 'submissions:all-account:configurable-table:render', 
    'submissions:account-create::view', 'account-broker-view::layout:render', 'account-broker-view:::view', 'account-broker-view::widget:render', 'agency-account::layout:render', 'agency-account:::view', 'agency-account::widget:render', 'agency-account::configurable-table:render', 
    'account-broker-view::configurable-table:render', 'submissions:all-ingest_policy_through_pd:configurable-table:render', 'submissions:all-ingest_policy_through_pd::view', 'submissions:ingest_policy_through_pd-create::view', '::nav-header:help-menu-opened', 
    'account-lines::duplicate-policy-modal:duplicate-rating', 'account-property-rating::duplicate-policy-modal:duplicate-rating', 
    'account-lines::construction-excess-rater:save-new-quote-click', 'account-lines::construction-excess-rater:create-document-click',
    '::duplicate-policy-modal:duplicate-rating', 'all-accounts:renewals:layout:render', 'all-accounts:renewals::view', 'all-accounts:renewals:configurable-table:render', 
    'all-accounts:renewals:widget:render', 'submissions:all-financial_lines::view', 'dashboard:team-insights:layout:render', 
    'dashboard:team-insights::view', 'dashboard:team-insights:widget:render', 'account-property-rating:pricing-detail:configurable-table:render',
    'account-property-rating:pricing-detail::view', 'account-property-rating:pricing-detail::open-ra-file-click',
    'account-property-rating:building-details:configurable-table:render', 'account-property-rating:building-details::view', 
    'submissions:exposures-definition::view', 'submissions:all-renewal::view', 'submissions:renewal-definition::view', 
    'all-accounts:new-business::view', 'all-accounts:new-business:layout:render', 'submissions:policy-create:configurable-table:render', 
    'submissions:renewal-create::view', 'submissions:renewal-definition::submit-click', 'submissions:renewal-create::submit-click',
    'submissions:all-renewal:configurable-table:render', 'all-accounts:new-business:accounts-table:account-click', 
    'account-lines::construction-excess-rater:modify-existing-quote-click', 'linked-email-thread-attachments:triaged_submissions-definition::document-download-click', 
    'submissions:all-auto::view', 'submissions:all-auto:configurable-table:render', 'account-workers-comp-rating:::view', 
    'account-workers-comp-rating:::change-rating-click', ':all-accounts::advanced-filters-opened', ':all-accounts:accounts-table:account-click',
    'account-broker-readonly-view::layout:render', 'account-broker-readonly-view:::view', 'account-broker-readonly-view::widget:render', 
    'triaged-submission:triaged_submissions-definition::winnability-click', 'triaged-submission:triaged_submissions-definition::appetite-click', 'assigned-email-thread:::email-thread-expansion', 
    'assigned-email-thread:::document-download-click', 'submissions:all-exposure_demo::view', 'submissions:all-exposure_demo:configurable-table:render', 'submissions:all-sashco_submission:configurable-table:render', 
    'submissions:all-sashco_submission::view', 'goals-and-rules:goals:configurable-table:render', 'goals-and-rules:goals::view', 'goals-and-rules:goal-definition::view', 
    'account-broker-readonly-view::configurable-table:render', 'submissions:all-terrorism::view', 'submissions:terrorism-create::view', 'submissions:all-terrorism:configurable-table:render', 'submissions:financial_lines-create::view', 
    'submissions:all-financial_lines:configurable-table:render', 'all-accounts:new-business:configurable-table:render', 'contacts::configurable-table:render', 'brokerage::configurable-table:render', 'brokerage::layout:render', 
    'brokerage:::view', 'brokerage::widget:render', 'complex-rules::configurable-table:render', 'classification-rules::configurable-table:render', 'rule:::view', 'rule::configurable-table:render', 
    'account-lines:::action-center-click', 'account-auto-rating:::change-rating-click', ':::account-click', 'account-property-rating::configurable-table:render', 'carriers::configurable-table:render', 
    'submissions:policy-definition::save-click', 'account-property-rating:perils:layers:delete-click', 'account-auto-rating::duplicate-policy-modal:duplicate-rating',
    'classification-rule:::view', 'classification-rule::configurable-table:render', 'submissions:policy-create::save-click', 'account-property-rating:::change-rating-click', 'goals-and-rules:rules:configurable-table:render', 
    'goals-and-rules:rules::view', 'goals-and-rules:new-rule::view', 'goals-and-rules:new-rule::close-click', 'reinsurance-binders::configurable-table:render', 'reinsurers-on-binders::configurable-table:render', 'reinsurers-on-binders:::view'
]

# %%
# Sidebar for feature selection
with st.sidebar:
    st.header("Feature Selection")
    current_selections = {}
    
    for feat in DROPDOWN_FEATURES:
        options = list(feature_to_idx[feat].keys())[1:]  # exclude default
        selection = st.selectbox(
            f"{feat.replace('_', ' ').title()}",
            options,
            key=feat
        )
        current_selections[feat] = feature_to_idx[feat].get(selection, 0)

# Main interface
st.title("Action Predictor")
# Out:
# 2025-02-23 23:28:44.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.797 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.797 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.797 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:44.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# Create buttons for event types in columns
cols = st.columns(4)
button_idx = 0
for action in event_actions:
    with cols[button_idx % 4]:
        if st.button(action):
            # Record current state + action
            record = {
                **current_selections,
                "event_type": action_to_idx.get(action, 0)
            }
            st.session_state.history.append(record)
            
            # Keep only last 8 steps
            if len(st.session_state.history) > 8:
                st.session_state.history = st.session_state.history[-8:]
    button_idx += 1
# Out:
# 2025-02-23 23:28:57.097 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.099 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.102 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.102 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.110 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.110 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.110 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.111 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.111 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.113 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.113 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.113 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.114 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.114 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.123 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.123 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.123 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.123 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.124 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.124 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.124 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.125 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.125 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.125 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.125 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.125 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.127 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.127 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.127 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.128 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.128 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.128 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.128 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.133 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.133 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.133 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.136 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.136 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.136 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.136 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.137 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.137 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.137 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.137 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.137 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.146 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.146 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.146 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.146 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.146 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.175 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.175 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.175 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.175 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.175 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.184 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.184 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.184 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.184 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.184 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
# 2025-02-23 23:28:57.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.373 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.373 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.373 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.373 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.375 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.375 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.375 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.375 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.375 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.376 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.376 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.376 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.376 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.379 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.379 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.379 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.379 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.380 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.380 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.380 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.380 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.380 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.383 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.383 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.383 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.383 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.384 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:28:57.384 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# Display recent history
st.subheader("Recent Actions")
history_display = [f"Step {i+1}: {h['event_type']}" for i, h in enumerate(st.session_state.history[-8:])]
st.write("\n".join(history_display))

# Prediction logic
if len(st.session_state.history) >= 8:
    # Prepare input tensor
    input_data = []
    for step in st.session_state.history[-8:]:
        step_features = [step.get(feat, 0) for feat in features_order]
        input_data.append(step_features)
    
    input_tensor = torch.LongTensor([input_data])  # (1, 8, 34)
    
    # Predict
    with torch.no_grad():
        logits = model(input_tensor)
        pred_idx = torch.argmax(logits).item()
    
    predicted_action = idx_to_action.get(pred_idx, "unknown")
    st.subheader(f"Predicted Next Action: {predicted_action}")

# Reset button
if st.button("Reset Session"):
    st.session_state.history = []
    st.experimental_rerun()
# Out:
# 2025-02-23 23:29:13.001 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:29:13.002 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:29:13.003 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:29:13.003 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:29:13.004 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:29:13.004 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:29:13.005 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:29:13.005 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:29:13.006 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:29:13.006 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:29:13.006 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:29:13.007 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-23 23:29:13.007 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
